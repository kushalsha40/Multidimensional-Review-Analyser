# %%
import sys
sys.path.append('../../src')

import sentiment
import emotion
import importlib
importlib.reload(sentiment)
importlib.reload(emotion)

print('sentiment', sentiment.__file__, hasattr(sentiment,'train_sentiment_model'))
print('emotion', emotion.__file__, hasattr(emotion,'get_emotion_score'))

from style import get_writing_style
from preprocessing import pipeline
from sentiment import train_sentiment_model
from emotion import get_emotion_score
# Out:
# sentiment /Users/kushal09/Documents/Career247 /Mini Project/NLP Project/imdb_analysis/notebooks/../../src/sentiment.py True
# emotion /Users/kushal09/Documents/Career247 /Mini Project/NLP Project/imdb_analysis/notebooks/../../src/emotion.py True

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')

import pandas as pd

data_path = '../data/imdb_dataset.csv'
df = pd.read_csv(data_path)

# quick run on subsample to avoid long training time during notebook development
df_small = df.sample(n=2000, random_state=42)

# run training
tfidf, model = train_sentiment_model(df_small, pipeline)

# evaluate on a sample text example
sample_text = "I loved this movie, but the story was a bit slow and frustrating"
clean_sample = pipeline(sample_text)
print('clean sample:', clean_sample)
prediction = model.predict(tfidf.transform([clean_sample]))[0]
print('prediction:', prediction)
print('emotion:', get_emotion_score(sample_text))
print('style:', get_writing_style(sample_text))
# Out:
# [nltk_data] Downloading package punkt to /Users/kushal09/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/kushal09/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/kushal09/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kushal09/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/kushal09/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
#               precision    recall  f1-score   support
#
#     negative       0.86      0.84      0.85       209
#     positive       0.83      0.85      0.84       191
#
# ...
